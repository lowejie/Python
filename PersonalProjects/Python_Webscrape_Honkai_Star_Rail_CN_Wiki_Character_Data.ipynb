# %% [markdown]
# <a href="https://colab.research.google.com/github/lowejie/Python/blob/main/Python_Webscrape_Honkai_Star_Rail_CN_Wiki_Character_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Python Web Scraping on CN Honkai Star Rail Wiki Character Data

# %% [markdown]
# This project serves as a practice on Web Scraping skills using Python library: BeautifulSoup to create a dataset detailing about the basic information related to the playable characters originated from the popular free-to-play role-playing gacha video game named Honkai: Star Rail published by mihoyo and released back in April 26th of 2023. It is the second game that is widely popularised after Genshin Impact for its immersive world-building and fascinating story-telling as well as attractive character designs. The story follows the main character: Traiblazer along with their companions on an intergalactic voyage to uncover the many mysteries about science-fantsy world itself.

# %% [markdown]
# Hereby present the objectives of this project:
#
# *   To practise Web Scraping using Python library: BeaultifulSoup to create datasets for use of personal projects.
# *   To familiarise with the various html tags and the methods to extract desired information from them.
#
# Other tools and libraries that will be used for this project include:
#
# *   Requests
# *   Pandas

# %% [markdown]
# Import the Python modules/libraries required.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# The source used is from the '角色筛选' section of '星穹铁道 Wiki' by '哔哩哔哩游戏中心' which translates to 'Character Filtering' section from the game wikipedia of the Honkai: Star Rail by the publisher, bilibili Games Center, which is the 'Games' section of the popular Youtube-equivalent platform from Mainland China: bilibili. As such, credible and official data related to the current playable characters are obtained from the unofficial Honkai: Star Rail Wiki.  The data gathered is from a table detailing about the attributes associated with each playable character like name, rarity, faction, etc.

# %%
url = "https://wiki.biligame.com/sr/%E8%A7%92%E8%89%B2%E7%AD%9B%E9%80%89"

# %% [markdown]
# Sending request to get only content from the url link

# %%
response = requests.get(url)
response = response.content

# %% [markdown]
# Turning the extracted information into html code.

# %%
soup = BeautifulSoup(response, "html.parser")

# %% [markdown]
# Search only for the table containing the data about the current playable characters.

# %%
table_char = soup.find('table', id='CardSelectTr')

# %% [markdown]
# To obtain the basic information and stats for each character, the process is split into 4 sections whereby each of the section features a different html tag that is common for storing some of the information of interest.

# %% [markdown]
# In the first section, it is observed that key information like name, rarity, path and element is stored within the html tag: img with attribute alt. The information is obtained from the alt attribute storing .png pictures for all of the current playable characters.

# %%
image = table_char.find_all('img')

basic = [alt['alt'] for alt in image]

basic
# Out:
# ['阿格莱雅.png',
#  '5星.png',
#  '记忆-白.png',
#  '雷.png',
#  '大黑塔.png',
#  '5星.png',
#  '智识-白.png',
#  '冰.png',
#  '开拓者•记忆.png',
#  '5星.png',
#  '记忆-白.png',
#  '冰.png',
#  '星期日.png',
#  '5星.png',
#  '同谐-白.png',
#  '虚数.png',
#  '忘归人.png',
#  '5星.png',
#  '虚无-白.png',
#  '火.png',
#  '乱破.png',
#  '5星.png',
#  '智识-白.png',
#  '虚数.png',
#  '灵砂.png',
#  '5星.png',
#  '丰饶-白.png',
#  '火.png',
#  '飞霄.png',
#  '5星.png',
#  '巡猎-白.png',
#  '风.png',
#  '貊泽.png',
#  '4星.png',
#  '巡猎-白.png',
#  '雷.png',
#  '椒丘.png',
#  '5星.png',
#  '虚无-白.png',
#  '火.png',
#  '云璃.png',
#  '5星.png',
#  '毁灭-白.png',
#  '物理.png',
#  '三月七•巡猎.png',
#  '4星.png',
#  '巡猎-白.png',
#  '虚数.png',
#  '翡翠.png',
#  '5星.png',
#  '智识-白.png',
#  '量子.png',
#  '流萤.png',
#  '5星.png',
#  '毁灭-白.png',
#  '火.png',
#  '波提欧.png',
#  '5星.png',
#  '巡猎-白.png',
#  '物理.png',
#  '知更鸟.png',
#  '5星.png',
#  '同谐-白.png',
#  '物理.png',
#  '开拓者•同谐.png',
#  '5星.png',
#  '同谐-白.png',
#  '虚数.png',
#  '砂金.png',
#  '5星.png',
#  '存护-白.png',
#  '虚数.png',
#  '黄泉.png',
#  '5星.png',
#  '虚无-白.png',
#  '雷.png',
#  '加拉赫.png',
#  '4星.png',
#  '丰饶-白.png',
#  '火.png',
#  '花火.png',
#  '5星.png',
#  '同谐-白.png',
#  '量子.png',
#  '黑天鹅.png',
#  '5星.png',
#  '虚无-白.png',
#  '风.png',
#  '米沙.png',
#  '4星.png',
#  '毁灭-白.png',
#  '冰.png',
#  '真理医生.png',
#  '5星.png',
#  '巡猎-白.png',
#  '虚数.png',
#  '阮•梅.png',
#  '5星.png',
#  '同谐-白.png',
#  '冰.png',
#  '雪衣.png',
#  '4星.png',
#  '毁灭-白.png',
#  '量子.png',
#  '银枝.png',
#  '5星.png',
#  '智识-白.png',
#  '物理.png',
#  '寒鸦.png',
#  '4星.png',
#  '同谐-白.png',
#  '物理.png',
#  '藿藿.png',
#  '5星.png',
#  '丰饶-白.png',
#  '风.png',
#  '托帕&账账.png',
#  '5星.png',
#  '巡猎-白.png',
#  '火.png',
#  '桂乃芬.png',
#  '4星.png',
#  '虚无-白.png',
#  '火.png',
#  '镜流.png',
#  '5星.png',
#  '毁灭-白.png',
#  '冰.png',
#  '符玄.png',
#  '5星.png',
#  '存护-白.png',
#  '量子.png',
#  '玲可.png',
#  '4星.png',
#  '丰饶-白.png',
#  '量子.png',
#  '丹恒•饮月.png',
#  '5星.png',
#  '毁灭-白.png',
#  '虚数.png',
#  '卡芙卡.png',
#  '5星.png',
#  '虚无-白.png',
#  '雷.png',
#  '卢卡.png',
#  '4星.png',
#  '虚无-白.png',
#  '物理.png',
#  '刃.png',
#  '5星.png',
#  '毁灭-白.png',
#  '风.png',
#  '罗刹.png',
#  '5星.png',
#  '丰饶-白.png',
#  '虚数.png',
#  '驭空.png',
#  '4星.png',
#  '同谐-白.png',
#  '虚数.png',
#  '银狼.png',
#  '5星.png',
#  '虚无-白.png',
#  '量子.png',
#  '景元.png',
#  '5星.png',
#  '智识-白.png',
#  '雷.png',
#  '希儿.png',
#  '5星.png',
#  '巡猎-白.png',
#  '量子.png',
#  '布洛妮娅.png',
#  '5星.png',
#  '同谐-白.png',
#  '风.png',
#  '瓦尔特.png',
#  '5星.png',
#  '虚无-白.png',
#  '虚数.png',
#  '克拉拉.png',
#  '5星.png',
#  '毁灭-白.png',
#  '物理.png',
#  '杰帕德.png',
#  '5星.png',
#  '存护-白.png',
#  '冰.png',
#  '姬子.png',
#  '5星.png',
#  '智识-白.png',
#  '火.png',
#  '白露.png',
#  '5星.png',
#  '丰饶-白.png',
#  '雷.png',
#  '彦卿.png',
#  '5星.png',
#  '巡猎-白.png',
#  '冰.png',
#  '开拓者•毁灭.png',
#  '5星.png',
#  '毁灭-白.png',
#  '物理.png',
#  '开拓者•存护.png',
#  '5星.png',
#  '存护-白.png',
#  '火.png',
#  '丹恒.png',
#  '4星.png',
#  '巡猎-白.png',
#  '风.png',
#  '艾丝妲.png',
#  '4星.png',
#  '同谐-白.png',
#  '火.png',
#  '三月七.png',
#  '4星.png',
#  '存护-白.png',
#  '冰.png',
#  '虎克.png',
#  '4星.png',
#  '毁灭-白.png',
#  '火.png',
#  '佩拉.png',
#  '4星.png',
#  '虚无-白.png',
#  '冰.png',
#  '桑博.png',
#  '4星.png',
#  '虚无-白.png',
#  '风.png',
#  '希露瓦.png',
#  '4星.png',
#  '智识-白.png',
#  '雷.png',
#  '娜塔莎.png',
#  '4星.png',
#  '丰饶-白.png',
#  '物理.png',
#  '素裳.png',
#  '4星.png',
#  '巡猎-白.png',
#  '物理.png',
#  '阿兰.png',
#  '4星.png',
#  '毁灭-白.png',
#  '雷.png',
#  '黑塔.png',
#  '4星.png',
#  '智识-白.png',
#  '冰.png',
#  '青雀.png',
#  '4星.png',
#  '智识-白.png',
#  '量子.png',
#  '停云.png',
#  '4星.png',
#  '同谐-白.png',
#  '雷.png']

# %% [markdown]
# After obtaining the information and storing them in a list, a for loop is used to process the elements such that only relevant information is stored and unwanted information are discarded.

# %%
char_info = []
for i in range(0,len(basic)):
    if '.' in basic[i]:
      item = basic[i].split('.')[0]
    if '-' in basic[i]:
      item = basic[i].split('-')[0]
    char_info.append(item)

char_info
# Out:
# ['阿格莱雅',
#  '5星',
#  '记忆',
#  '雷',
#  '大黑塔',
#  '5星',
#  '智识',
#  '冰',
#  '开拓者•记忆',
#  '5星',
#  '记忆',
#  '冰',
#  '星期日',
#  '5星',
#  '同谐',
#  '虚数',
#  '忘归人',
#  '5星',
#  '虚无',
#  '火',
#  '乱破',
#  '5星',
#  '智识',
#  '虚数',
#  '灵砂',
#  '5星',
#  '丰饶',
#  '火',
#  '飞霄',
#  '5星',
#  '巡猎',
#  '风',
#  '貊泽',
#  '4星',
#  '巡猎',
#  '雷',
#  '椒丘',
#  '5星',
#  '虚无',
#  '火',
#  '云璃',
#  '5星',
#  '毁灭',
#  '物理',
#  '三月七•巡猎',
#  '4星',
#  '巡猎',
#  '虚数',
#  '翡翠',
#  '5星',
#  '智识',
#  '量子',
#  '流萤',
#  '5星',
#  '毁灭',
#  '火',
#  '波提欧',
#  '5星',
#  '巡猎',
#  '物理',
#  '知更鸟',
#  '5星',
#  '同谐',
#  '物理',
#  '开拓者•同谐',
#  '5星',
#  '同谐',
#  '虚数',
#  '砂金',
#  '5星',
#  '存护',
#  '虚数',
#  '黄泉',
#  '5星',
#  '虚无',
#  '雷',
#  '加拉赫',
#  '4星',
#  '丰饶',
#  '火',
#  '花火',
#  '5星',
#  '同谐',
#  '量子',
#  '黑天鹅',
#  '5星',
#  '虚无',
#  '风',
#  '米沙',
#  '4星',
#  '毁灭',
#  '冰',
#  '真理医生',
#  '5星',
#  '巡猎',
#  '虚数',
#  '阮•梅',
#  '5星',
#  '同谐',
#  '冰',
#  '雪衣',
#  '4星',
#  '毁灭',
#  '量子',
#  '银枝',
#  '5星',
#  '智识',
#  '物理',
#  '寒鸦',
#  '4星',
#  '同谐',
#  '物理',
#  '藿藿',
#  '5星',
#  '丰饶',
#  '风',
#  '托帕&账账',
#  '5星',
#  '巡猎',
#  '火',
#  '桂乃芬',
#  '4星',
#  '虚无',
#  '火',
#  '镜流',
#  '5星',
#  '毁灭',
#  '冰',
#  '符玄',
#  '5星',
#  '存护',
#  '量子',
#  '玲可',
#  '4星',
#  '丰饶',
#  '量子',
#  '丹恒•饮月',
#  '5星',
#  '毁灭',
#  '虚数',
#  '卡芙卡',
#  '5星',
#  '虚无',
#  '雷',
#  '卢卡',
#  '4星',
#  '虚无',
#  '物理',
#  '刃',
#  '5星',
#  '毁灭',
#  '风',
#  '罗刹',
#  '5星',
#  '丰饶',
#  '虚数',
#  '驭空',
#  '4星',
#  '同谐',
#  '虚数',
#  '银狼',
#  '5星',
#  '虚无',
#  '量子',
#  '景元',
#  '5星',
#  '智识',
#  '雷',
#  '希儿',
#  '5星',
#  '巡猎',
#  '量子',
#  '布洛妮娅',
#  '5星',
#  '同谐',
#  '风',
#  '瓦尔特',
#  '5星',
#  '虚无',
#  '虚数',
#  '克拉拉',
#  '5星',
#  '毁灭',
#  '物理',
#  '杰帕德',
#  '5星',
#  '存护',
#  '冰',
#  '姬子',
#  '5星',
#  '智识',
#  '火',
#  '白露',
#  '5星',
#  '丰饶',
#  '雷',
#  '彦卿',
#  '5星',
#  '巡猎',
#  '冰',
#  '开拓者•毁灭',
#  '5星',
#  '毁灭',
#  '物理',
#  '开拓者•存护',
#  '5星',
#  '存护',
#  '火',
#  '丹恒',
#  '4星',
#  '巡猎',
#  '风',
#  '艾丝妲',
#  '4星',
#  '同谐',
#  '火',
#  '三月七',
#  '4星',
#  '存护',
#  '冰',
#  '虎克',
#  '4星',
#  '毁灭',
#  '火',
#  '佩拉',
#  '4星',
#  '虚无',
#  '冰',
#  '桑博',
#  '4星',
#  '虚无',
#  '风',
#  '希露瓦',
#  '4星',
#  '智识',
#  '雷',
#  '娜塔莎',
#  '4星',
#  '丰饶',
#  '物理',
#  '素裳',
#  '4星',
#  '巡猎',
#  '物理',
#  '阿兰',
#  '4星',
#  '毁灭',
#  '雷',
#  '黑塔',
#  '4星',
#  '智识',
#  '冰',
#  '青雀',
#  '4星',
#  '智识',
#  '量子',
#  '停云',
#  '4星',
#  '同谐',
#  '雷']

# %% [markdown]
# There are total of 65 current playable characters as of 16/2/2025 and 4 information associated with each character is obtained which translates to 65 * 4 = 260 elements present in the list.

# %%
len(char_info)
# Out:
# 260

# %% [markdown]
# In the next section, information like gender, faction and base stats are stored in the html tag with class 'hidden-xs'.

# %%
td = table_char.find_all('td', class_="hidden-xs")

td
# Out:
# [<td class="hidden-xs"><a href="/sr/%E9%98%BF%E6%A0%BC%E8%8E%B1%E9%9B%85" title="阿格莱雅">阿格莱雅</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">翁法罗斯</td>,
#  <td class="hidden-xs">1242</td>,
#  <td class="hidden-xs">699</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">350</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%A4%A7%E9%BB%91%E5%A1%94" title="大黑塔">大黑塔</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">空间站「黑塔」</td>,
#  <td class="hidden-xs">1164</td>,
#  <td class="hidden-xs">679</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">99</td>,
#  <td class="hidden-xs">220</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%BC%80%E6%8B%93%E8%80%85%E2%80%A2%E8%AE%B0%E5%BF%86" title="开拓者•记忆">开拓者•记忆</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男, 女</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">1203</td>,
#  <td class="hidden-xs">620</td>,
#  <td class="hidden-xs">460</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs">160</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%98%9F%E6%9C%9F%E6%97%A5" title="星期日">星期日</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">银河</td>,
#  <td class="hidden-xs">1241</td>,
#  <td class="hidden-xs">640</td>,
#  <td class="hidden-xs">533</td>,
#  <td class="hidden-xs">96</td>,
#  <td class="hidden-xs">130</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%BF%98%E5%BD%92%E4%BA%BA" title="忘归人">忘归人</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1125</td>,
#  <td class="hidden-xs">582</td>,
#  <td class="hidden-xs">558</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">130</td>,
#  <td class="hidden-xs"><a href="/sr/%E4%B9%B1%E7%A0%B4" title="乱破">乱破</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">巡海游侠</td>,
#  <td class="hidden-xs">1086</td>,
#  <td class="hidden-xs">717</td>,
#  <td class="hidden-xs">460</td>,
#  <td class="hidden-xs">96</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%81%B5%E7%A0%82" title="灵砂">灵砂</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1358</td>,
#  <td class="hidden-xs">679</td>,
#  <td class="hidden-xs">437</td>,
#  <td class="hidden-xs">98</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%A3%9E%E9%9C%84" title="飞霄">飞霄</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「曜青」</td>,
#  <td class="hidden-xs">1047</td>,
#  <td class="hidden-xs">601</td>,
#  <td class="hidden-xs">388</td>,
#  <td class="hidden-xs">112</td>,
#  <td class="hidden-xs">12点【飞黄】</td>,
#  <td class="hidden-xs"><a href="/sr/%E8%B2%8A%E6%B3%BD" title="貊泽">貊泽</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">仙舟「曜青」</td>,
#  <td class="hidden-xs">811</td>,
#  <td class="hidden-xs">599</td>,
#  <td class="hidden-xs">352</td>,
#  <td class="hidden-xs">111</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%A4%92%E4%B8%98" title="椒丘">椒丘</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">仙舟「曜青」</td>,
#  <td class="hidden-xs">1358</td>,
#  <td class="hidden-xs">601</td>,
#  <td class="hidden-xs">509</td>,
#  <td class="hidden-xs">98</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs"><a href="/sr/%E4%BA%91%E7%92%83" title="云璃">云璃</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「朱明」</td>,
#  <td class="hidden-xs">1358</td>,
#  <td class="hidden-xs">679</td>,
#  <td class="hidden-xs">460</td>,
#  <td class="hidden-xs">94</td>,
#  <td class="hidden-xs">240</td>,
#  <td class="hidden-xs"><a href="/sr/%E4%B8%89%E6%9C%88%E4%B8%83%E2%80%A2%E5%B7%A1%E7%8C%8E" title="三月七•巡猎">三月七•巡猎</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">1058</td>,
#  <td class="hidden-xs">564</td>,
#  <td class="hidden-xs">441</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%BF%A1%E7%BF%A0" title="翡翠">翡翠</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">星际和平公司</td>,
#  <td class="hidden-xs">1086</td>,
#  <td class="hidden-xs">659</td>,
#  <td class="hidden-xs">509</td>,
#  <td class="hidden-xs">103</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%B5%81%E8%90%A4" title="流萤">流萤</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">星核猎手</td>,
#  <td class="hidden-xs">814</td>,
#  <td class="hidden-xs">523</td>,
#  <td class="hidden-xs">776</td>,
#  <td class="hidden-xs">104</td>,
#  <td class="hidden-xs">240</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%B3%A2%E6%8F%90%E6%AC%A7" title="波提欧">波提欧</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">巡海游侠</td>,
#  <td class="hidden-xs">1203</td>,
#  <td class="hidden-xs">620</td>,
#  <td class="hidden-xs">436</td>,
#  <td class="hidden-xs">107</td>,
#  <td class="hidden-xs">115</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%9F%A5%E6%9B%B4%E9%B8%9F" title="知更鸟">知更鸟</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">匹诺康尼</td>,
#  <td class="hidden-xs">1280</td>,
#  <td class="hidden-xs">640</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">160</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%BC%80%E6%8B%93%E8%80%85%E2%80%A2%E5%90%8C%E8%B0%90" title="开拓者•同谐">开拓者•同谐</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男, 女</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">1086</td>,
#  <td class="hidden-xs">446</td>,
#  <td class="hidden-xs">679</td>,
#  <td class="hidden-xs">105</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%A0%82%E9%87%91" title="砂金">砂金</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">星际和平公司</td>,
#  <td class="hidden-xs">1203</td>,
#  <td class="hidden-xs">446</td>,
#  <td class="hidden-xs">654</td>,
#  <td class="hidden-xs">106</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%BB%84%E6%B3%89" title="黄泉">黄泉</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">自灭者</td>,
#  <td class="hidden-xs">1125</td>,
#  <td class="hidden-xs">698</td>,
#  <td class="hidden-xs">436</td>,
#  <td class="hidden-xs">101</td>,
#  <td class="hidden-xs">9点【残梦】</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%8A%A0%E6%8B%89%E8%B5%AB" title="加拉赫">加拉赫</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">匹诺康尼</td>,
#  <td class="hidden-xs">1305</td>,
#  <td class="hidden-xs">529</td>,
#  <td class="hidden-xs">441</td>,
#  <td class="hidden-xs">98</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E8%8A%B1%E7%81%AB" title="花火">花火</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">假面愚者</td>,
#  <td class="hidden-xs">1397</td>,
#  <td class="hidden-xs">523</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">101</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%BB%91%E5%A4%A9%E9%B9%85" title="黑天鹅">黑天鹅</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">流光忆庭</td>,
#  <td class="hidden-xs">1086</td>,
#  <td class="hidden-xs">659</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%B1%B3%E6%B2%99" title="米沙">米沙</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">匹诺康尼</td>,
#  <td class="hidden-xs">1270</td>,
#  <td class="hidden-xs">599</td>,
#  <td class="hidden-xs">396</td>,
#  <td class="hidden-xs">96</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%9C%9F%E7%90%86%E5%8C%BB%E7%94%9F" title="真理医生">真理医生</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">博识学会</td>,
#  <td class="hidden-xs">1047</td>,
#  <td class="hidden-xs">776</td>,
#  <td class="hidden-xs">460</td>,
#  <td class="hidden-xs">103</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%98%AE%E2%80%A2%E6%A2%85" title="阮•梅">阮•梅</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">空间站「黑塔」</td>,
#  <td class="hidden-xs">1086</td>,
#  <td class="hidden-xs">659</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">104</td>,
#  <td class="hidden-xs">130</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%9B%AA%E8%A1%A3" title="雪衣">雪衣</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1058</td>,
#  <td class="hidden-xs">599</td>,
#  <td class="hidden-xs">396</td>,
#  <td class="hidden-xs">103</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%93%B6%E6%9E%9D" title="银枝">银枝</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">纯美骑士团</td>,
#  <td class="hidden-xs">1047</td>,
#  <td class="hidden-xs">737</td>,
#  <td class="hidden-xs">363</td>,
#  <td class="hidden-xs">103</td>,
#  <td class="hidden-xs">180</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%AF%92%E9%B8%A6" title="寒鸦">寒鸦</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">917</td>,
#  <td class="hidden-xs">564</td>,
#  <td class="hidden-xs">352</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E8%97%BF%E8%97%BF" title="藿藿">藿藿</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1358</td>,
#  <td class="hidden-xs">601</td>,
#  <td class="hidden-xs">509</td>,
#  <td class="hidden-xs">98</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%89%98%E5%B8%95%26%E8%B4%A6%E8%B4%A6" title="托帕&amp;账账">托帕&amp;账账</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">星际和平公司</td>,
#  <td class="hidden-xs">931</td>,
#  <td class="hidden-xs">622</td>,
#  <td class="hidden-xs">412</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs">130</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%A1%82%E4%B9%83%E8%8A%AC" title="桂乃芬">桂乃芬</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">882</td>,
#  <td class="hidden-xs">582</td>,
#  <td class="hidden-xs">441</td>,
#  <td class="hidden-xs">106</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%95%9C%E6%B5%81" title="镜流">镜流</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1435</td>,
#  <td class="hidden-xs">679</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">96</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%AC%A6%E7%8E%84" title="符玄">符玄</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1474</td>,
#  <td class="hidden-xs">465</td>,
#  <td class="hidden-xs">606</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs">135</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%8E%B2%E5%8F%AF" title="玲可">玲可</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">1058</td>,
#  <td class="hidden-xs">493</td>,
#  <td class="hidden-xs">551</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs"><a href="/sr/%E4%B8%B9%E6%81%92%E2%80%A2%E9%A5%AE%E6%9C%88" title="丹恒•饮月">丹恒•饮月</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1241</td>,
#  <td class="hidden-xs">698</td>,
#  <td class="hidden-xs">363</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%8D%A1%E8%8A%99%E5%8D%A1" title="卡芙卡">卡芙卡</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">星核猎手</td>,
#  <td class="hidden-xs">1086</td>,
#  <td class="hidden-xs">679</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%8D%A2%E5%8D%A1" title="卢卡">卢卡</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">917</td>,
#  <td class="hidden-xs">582</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">103</td>,
#  <td class="hidden-xs">130</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%88%83" title="刃">刃</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">星核猎手</td>,
#  <td class="hidden-xs">1358</td>,
#  <td class="hidden-xs">543</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">97</td>,
#  <td class="hidden-xs">130</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%BD%97%E5%88%B9" title="罗刹">罗刹</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1280</td>,
#  <td class="hidden-xs">756</td>,
#  <td class="hidden-xs">363</td>,
#  <td class="hidden-xs">101</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%A9%AD%E7%A9%BA" title="驭空">驭空</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">917</td>,
#  <td class="hidden-xs">599</td>,
#  <td class="hidden-xs">374</td>,
#  <td class="hidden-xs">107</td>,
#  <td class="hidden-xs">130</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%93%B6%E7%8B%BC" title="银狼">银狼</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">星核猎手</td>,
#  <td class="hidden-xs">1047</td>,
#  <td class="hidden-xs">640</td>,
#  <td class="hidden-xs">460</td>,
#  <td class="hidden-xs">107</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%99%AF%E5%85%83" title="景元">景元</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1164</td>,
#  <td class="hidden-xs">698</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">99</td>,
#  <td class="hidden-xs">130</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%B8%8C%E5%84%BF" title="希儿">希儿</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">931</td>,
#  <td class="hidden-xs">640</td>,
#  <td class="hidden-xs">363</td>,
#  <td class="hidden-xs">115</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%B8%83%E6%B4%9B%E5%A6%AE%E5%A8%85" title="布洛妮娅">布洛妮娅</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">1241</td>,
#  <td class="hidden-xs">582</td>,
#  <td class="hidden-xs">533</td>,
#  <td class="hidden-xs">99</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%93%A6%E5%B0%94%E7%89%B9" title="瓦尔特">瓦尔特</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">1125</td>,
#  <td class="hidden-xs">620</td>,
#  <td class="hidden-xs">509</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%85%8B%E6%8B%89%E6%8B%89" title="克拉拉">克拉拉</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">1241</td>,
#  <td class="hidden-xs">737</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">90</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%9D%B0%E5%B8%95%E5%BE%B7" title="杰帕德">杰帕德</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">1397</td>,
#  <td class="hidden-xs">543</td>,
#  <td class="hidden-xs">654</td>,
#  <td class="hidden-xs">92</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%A7%AC%E5%AD%90" title="姬子">姬子</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">1047</td>,
#  <td class="hidden-xs">756</td>,
#  <td class="hidden-xs">436</td>,
#  <td class="hidden-xs">96</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%99%BD%E9%9C%B2" title="白露">白露</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1319</td>,
#  <td class="hidden-xs">562</td>,
#  <td class="hidden-xs">485</td>,
#  <td class="hidden-xs">98</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%BD%A6%E5%8D%BF" title="彦卿">彦卿</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">892</td>,
#  <td class="hidden-xs">679</td>,
#  <td class="hidden-xs">412</td>,
#  <td class="hidden-xs">109</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%BC%80%E6%8B%93%E8%80%85%E2%80%A2%E6%AF%81%E7%81%AD" title="开拓者•毁灭">开拓者•毁灭</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男, 女</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">1203</td>,
#  <td class="hidden-xs">620</td>,
#  <td class="hidden-xs">460</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%BC%80%E6%8B%93%E8%80%85%E2%80%A2%E5%AD%98%E6%8A%A4" title="开拓者•存护">开拓者•存护</a></td>,
#  <td class="hidden-xs"><img alt="5星.png" data-file-height="27" data-file-width="99" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/52px-5%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png/77px-5%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/c/c7/g380fo4o5accoa1rmlckz3e24vpx23e.png 2x" width="52"/></td>,
#  <td class="hidden-xs">男, 女</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">1241</td>,
#  <td class="hidden-xs">601</td>,
#  <td class="hidden-xs">606</td>,
#  <td class="hidden-xs">95</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E4%B8%B9%E6%81%92" title="丹恒">丹恒</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">882</td>,
#  <td class="hidden-xs">546</td>,
#  <td class="hidden-xs">396</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs"><a href="/sr/%E8%89%BE%E4%B8%9D%E5%A6%B2" title="艾丝妲">艾丝妲</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">空间站「黑塔」</td>,
#  <td class="hidden-xs">1023</td>,
#  <td class="hidden-xs">511</td>,
#  <td class="hidden-xs">463</td>,
#  <td class="hidden-xs">106</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E4%B8%89%E6%9C%88%E4%B8%83" title="三月七">三月七</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">星穹列车</td>,
#  <td class="hidden-xs">1058</td>,
#  <td class="hidden-xs">511</td>,
#  <td class="hidden-xs">573</td>,
#  <td class="hidden-xs">101</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E8%99%8E%E5%85%8B" title="虎克">虎克</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">1340</td>,
#  <td class="hidden-xs">617</td>,
#  <td class="hidden-xs">352</td>,
#  <td class="hidden-xs">94</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E4%BD%A9%E6%8B%89" title="佩拉">佩拉</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">987</td>,
#  <td class="hidden-xs">546</td>,
#  <td class="hidden-xs">463</td>,
#  <td class="hidden-xs">105</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E6%A1%91%E5%8D%9A" title="桑博">桑博</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">1023</td>,
#  <td class="hidden-xs">617</td>,
#  <td class="hidden-xs">396</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%B8%8C%E9%9C%B2%E7%93%A6" title="希露瓦">希露瓦</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">917</td>,
#  <td class="hidden-xs">652</td>,
#  <td class="hidden-xs">374</td>,
#  <td class="hidden-xs">104</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%A8%9C%E5%A1%94%E8%8E%8E" title="娜塔莎">娜塔莎</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">贝洛伯格</td>,
#  <td class="hidden-xs">1164</td>,
#  <td class="hidden-xs">476</td>,
#  <td class="hidden-xs">507</td>,
#  <td class="hidden-xs">98</td>,
#  <td class="hidden-xs">90</td>,
#  <td class="hidden-xs"><a href="/sr/%E7%B4%A0%E8%A3%B3" title="素裳">素裳</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">917</td>,
#  <td class="hidden-xs">564</td>,
#  <td class="hidden-xs">418</td>,
#  <td class="hidden-xs">107</td>,
#  <td class="hidden-xs">120</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%98%BF%E5%85%B0" title="阿兰">阿兰</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">男</td>,
#  <td class="hidden-xs">空间站「黑塔」</td>,
#  <td class="hidden-xs">1199</td>,
#  <td class="hidden-xs">599</td>,
#  <td class="hidden-xs">330</td>,
#  <td class="hidden-xs">102</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%BB%91%E5%A1%94" title="黑塔">黑塔</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">空间站「黑塔」</td>,
#  <td class="hidden-xs">952</td>,
#  <td class="hidden-xs">582</td>,
#  <td class="hidden-xs">396</td>,
#  <td class="hidden-xs">100</td>,
#  <td class="hidden-xs">110</td>,
#  <td class="hidden-xs"><a href="/sr/%E9%9D%92%E9%9B%80" title="青雀">青雀</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">1023</td>,
#  <td class="hidden-xs">652</td>,
#  <td class="hidden-xs">441</td>,
#  <td class="hidden-xs">98</td>,
#  <td class="hidden-xs">140</td>,
#  <td class="hidden-xs"><a href="/sr/%E5%81%9C%E4%BA%91" title="停云">停云</a></td>,
#  <td class="hidden-xs"><img alt="4星.png" data-file-height="27" data-file-width="84" decoding="async" height="14" loading="lazy" src="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/44px-4%E6%98%9F.png" srcset="https://patchwiki.biligame.com/images/sr/thumb/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png/66px-4%E6%98%9F.png 1.5x, https://patchwiki.biligame.com/images/sr/9/9c/m5jb29e4h1q35a5etj8t7ehaemzr3kk.png 2x" width="44"/></td>,
#  <td class="hidden-xs">女</td>,
#  <td class="hidden-xs">仙舟「罗浮」</td>,
#  <td class="hidden-xs">846</td>,
#  <td class="hidden-xs">529</td>,
#  <td class="hidden-xs">396</td>,
#  <td class="hidden-xs">112</td>,
#  <td class="hidden-xs">130</td>]

# %% [markdown]
# It is observed that the desired information is always stored in the third until ninth position [index 2 till 8] and thus a for loop is created to run through the previous list to obtain the desired information and store them in a new list.

# %%
char_info2 = []
for i in range(2,len(td),9):
  char_info2.extend(td[i:i+7])

char_info2 = [item.text for item in char_info2]

char_info2
# Out:
# ['女',
#  '翁法罗斯',
#  '1242',
#  '699',
#  '485',
#  '102',
#  '350',
#  '女',
#  '空间站「黑塔」',
#  '1164',
#  '679',
#  '485',
#  '99',
#  '220',
#  '男, 女',
#  '星穹列车',
#  '1203',
#  '620',
#  '460',
#  '100',
#  '160',
#  '男',
#  '银河',
#  '1241',
#  '640',
#  '533',
#  '96',
#  '130',
#  '女',
#  '仙舟「罗浮」',
#  '1125',
#  '582',
#  '558',
#  '102',
#  '130',
#  '女',
#  '巡海游侠',
#  '1086',
#  '717',
#  '460',
#  '96',
#  '140',
#  '女',
#  '仙舟「罗浮」',
#  '1358',
#  '679',
#  '437',
#  '98',
#  '110',
#  '女',
#  '仙舟「曜青」',
#  '1047',
#  '601',
#  '388',
#  '112',
#  '12点【飞黄】',
#  '男',
#  '仙舟「曜青」',
#  '811',
#  '599',
#  '352',
#  '111',
#  '120',
#  '男',
#  '仙舟「曜青」',
#  '1358',
#  '601',
#  '509',
#  '98',
#  '100',
#  '女',
#  '仙舟「朱明」',
#  '1358',
#  '679',
#  '460',
#  '94',
#  '240',
#  '女',
#  '星穹列车',
#  '1058',
#  '564',
#  '441',
#  '102',
#  '110',
#  '女',
#  '星际和平公司',
#  '1086',
#  '659',
#  '509',
#  '103',
#  '140',
#  '女',
#  '星核猎手',
#  '814',
#  '523',
#  '776',
#  '104',
#  '240',
#  '男',
#  '巡海游侠',
#  '1203',
#  '620',
#  '436',
#  '107',
#  '115',
#  '女',
#  '匹诺康尼',
#  '1280',
#  '640',
#  '485',
#  '102',
#  '160',
#  '男, 女',
#  '星穹列车',
#  '1086',
#  '446',
#  '679',
#  '105',
#  '140',
#  '男',
#  '星际和平公司',
#  '1203',
#  '446',
#  '654',
#  '106',
#  '110',
#  '女',
#  '自灭者',
#  '1125',
#  '698',
#  '436',
#  '101',
#  '9点【残梦】',
#  '男',
#  '匹诺康尼',
#  '1305',
#  '529',
#  '441',
#  '98',
#  '110',
#  '女',
#  '假面愚者',
#  '1397',
#  '523',
#  '485',
#  '101',
#  '110',
#  '女',
#  '流光忆庭',
#  '1086',
#  '659',
#  '485',
#  '102',
#  '120',
#  '男',
#  '匹诺康尼',
#  '1270',
#  '599',
#  '396',
#  '96',
#  '100',
#  '男',
#  '博识学会',
#  '1047',
#  '776',
#  '460',
#  '103',
#  '140',
#  '女',
#  '空间站「黑塔」',
#  '1086',
#  '659',
#  '485',
#  '104',
#  '130',
#  '女',
#  '仙舟「罗浮」',
#  '1058',
#  '599',
#  '396',
#  '103',
#  '120',
#  '男',
#  '纯美骑士团',
#  '1047',
#  '737',
#  '363',
#  '103',
#  '180',
#  '女',
#  '仙舟「罗浮」',
#  '917',
#  '564',
#  '352',
#  '110',
#  '140',
#  '女',
#  '仙舟「罗浮」',
#  '1358',
#  '601',
#  '509',
#  '98',
#  '140',
#  '女',
#  '星际和平公司',
#  '931',
#  '622',
#  '412',
#  '110',
#  '130',
#  '女',
#  '仙舟「罗浮」',
#  '882',
#  '582',
#  '441',
#  '106',
#  '120',
#  '女',
#  '仙舟「罗浮」',
#  '1435',
#  '679',
#  '485',
#  '96',
#  '140',
#  '女',
#  '仙舟「罗浮」',
#  '1474',
#  '465',
#  '606',
#  '100',
#  '135',
#  '女',
#  '贝洛伯格',
#  '1058',
#  '493',
#  '551',
#  '100',
#  '100',
#  '男',
#  '仙舟「罗浮」',
#  '1241',
#  '698',
#  '363',
#  '102',
#  '140',
#  '女',
#  '星核猎手',
#  '1086',
#  '679',
#  '485',
#  '100',
#  '120',
#  '男',
#  '贝洛伯格',
#  '917',
#  '582',
#  '485',
#  '103',
#  '130',
#  '男',
#  '星核猎手',
#  '1358',
#  '543',
#  '485',
#  '97',
#  '130',
#  '男',
#  '仙舟「罗浮」',
#  '1280',
#  '756',
#  '363',
#  '101',
#  '100',
#  '女',
#  '仙舟「罗浮」',
#  '917',
#  '599',
#  '374',
#  '107',
#  '130',
#  '女',
#  '星核猎手',
#  '1047',
#  '640',
#  '460',
#  '107',
#  '110',
#  '男',
#  '仙舟「罗浮」',
#  '1164',
#  '698',
#  '485',
#  '99',
#  '130',
#  '女',
#  '贝洛伯格',
#  '931',
#  '640',
#  '363',
#  '115',
#  '120',
#  '女',
#  '贝洛伯格',
#  '1241',
#  '582',
#  '533',
#  '99',
#  '120',
#  '男',
#  '星穹列车',
#  '1125',
#  '620',
#  '509',
#  '102',
#  '120',
#  '女',
#  '贝洛伯格',
#  '1241',
#  '737',
#  '485',
#  '90',
#  '110',
#  '男',
#  '贝洛伯格',
#  '1397',
#  '543',
#  '654',
#  '92',
#  '100',
#  '女',
#  '星穹列车',
#  '1047',
#  '756',
#  '436',
#  '96',
#  '120',
#  '女',
#  '仙舟「罗浮」',
#  '1319',
#  '562',
#  '485',
#  '98',
#  '100',
#  '男',
#  '仙舟「罗浮」',
#  '892',
#  '679',
#  '412',
#  '109',
#  '140',
#  '男, 女',
#  '星穹列车',
#  '1203',
#  '620',
#  '460',
#  '100',
#  '120',
#  '男, 女',
#  '星穹列车',
#  '1241',
#  '601',
#  '606',
#  '95',
#  '120',
#  '男',
#  '星穹列车',
#  '882',
#  '546',
#  '396',
#  '110',
#  '100',
#  '女',
#  '空间站「黑塔」',
#  '1023',
#  '511',
#  '463',
#  '106',
#  '120',
#  '女',
#  '星穹列车',
#  '1058',
#  '511',
#  '573',
#  '101',
#  '120',
#  '女',
#  '贝洛伯格',
#  '1340',
#  '617',
#  '352',
#  '94',
#  '120',
#  '女',
#  '贝洛伯格',
#  '987',
#  '546',
#  '463',
#  '105',
#  '110',
#  '男',
#  '贝洛伯格',
#  '1023',
#  '617',
#  '396',
#  '102',
#  '120',
#  '女',
#  '贝洛伯格',
#  '917',
#  '652',
#  '374',
#  '104',
#  '100',
#  '女',
#  '贝洛伯格',
#  '1164',
#  '476',
#  '507',
#  '98',
#  '90',
#  '女',
#  '仙舟「罗浮」',
#  '917',
#  '564',
#  '418',
#  '107',
#  '120',
#  '男',
#  '空间站「黑塔」',
#  '1199',
#  '599',
#  '330',
#  '102',
#  '110',
#  '女',
#  '空间站「黑塔」',
#  '952',
#  '582',
#  '396',
#  '100',
#  '110',
#  '女',
#  '仙舟「罗浮」',
#  '1023',
#  '652',
#  '441',
#  '98',
#  '140',
#  '女',
#  '仙舟「罗浮」',
#  '846',
#  '529',
#  '396',
#  '112',
#  '130']

# %% [markdown]
# Again, with 65 current playable characters as of 16/2/2025 and 7 information is obtained for each character, 65 * 7 = 455 elements present in the new list.

# %%
len(char_info2)
# Out:
# 455

# %% [markdown]
# The next section finds all html tag span with class tag-data-1 containing information about the brief description in words about the functionality, damage types, buffs offered, etc of each character.

# %%
span1 = table_char.find_all('span', class_="tag-data-1")

char_tag1 = [item.text for item in span1]

char_tag1
# Out:
# ['忆灵、高速主C',
#  '对群输出、攻击强化',
#  '忆灵、真实伤害',
#  '效果解除、立即行动、增伤、暴击率提升、暴击伤害提升、能量恢复、能量、召唤物立即行动、战技点恢复',
#  '击破特攻提升、无视弱点削韧、行动延后、减防、超击破、击破特攻、战技点恢复',
#  '技能强化、无视弱点削韧、群攻、额外回合、弱点击破效率、击破特攻、额外伤害、伤害倍率、快速移动、秘技无受击、能量、超击破、击破易伤',
#  '召唤、自身召唤物行动提前、治疗、击破易伤、群攻、额外伤害、追加攻击、攻击力、治疗量、能量',
#  '追加攻击、无视弱点削韧、伤害倍率、自身伤害提升、攻击力、暴击伤害、快速移动、秘技牵引、特殊能量',
#  '追加攻击、行动提前、战技点恢复、追加攻击易伤、附加伤害',
#  '终结技易伤、易伤、持续伤害、特殊领域、群攻、攻击力、能量',
#  '反击、自身治疗、能量、嘲讽、暴击伤害、额外伤害、自身减伤、攻击力',
#  '速度提升、附加伤害、技能强化、削韧值、立即行动、自身伤害提升。攻击段数提升、能量、击破特攻提升、行动提前、暴伤提升',
#  '追加攻击、暴击伤害、攻击力、群攻、速度提升、额外伤害、消耗队友生命值、自身追击伤害提升、秘技无受击、秘技群攻',
#  '技能强化、击破特攻、弱点击破效率、速度、弱点植入、无视弱点削韧、秘技群攻、秘技无受击、消耗生命值、能量、自身减伤、自身治疗、快速移动、自身行动提前、效果抵抗、超击破、削韧值、自身击破易伤、自身效果解除',
#  '强化技能、弱点植入、嘲讽、行动延后、能量、暴击率、暴击伤害、自身减伤、自身易伤',
#  '立即行动、能量、特殊领域、秘技诱敌、秘技无受击、增伤、加攻、附加伤害、控制抵抗、暴伤提升、自身行动提前',
#  '能量、击破特攻提升、超击破、行动延后',
#  '群体护盾、护盾叠加、随机、暴伤提升、效果抵抗提升、控制抵抗、追加攻击、加防、暴击率',
#  '特殊能量、无视弱点削韧、减抗、负面效果参照、探索便利、秘技无受击、自身普攻伤害提升、自身战技伤害提升、自身终结技伤害提升、自身伤害提升、额外伤害、群攻、快速移动、伤害额外提高',
#  '技能强化、治疗、群攻、自身行动提前、攻击治疗、击破易伤、治疗量',
#  '暴击伤害、行动提前、战技点恢复、增伤、战技点上限、秘技无受击、加攻、能量',
#  '持续伤害、减防、自身伤害提升、额外效果、易伤、群攻、自身无视防御力',
#  '暴击伤害、效果命中、特殊领域、能量、附加伤害、战技点恢复、冻结、秘技无受击',
#  '追加攻击、负面效果参照、暴击率、暴击伤害、效果抵抗降低、自身伤害提升、特殊领域、减速、秘技无受击',
#  '速度提升、增伤、能量、行动延后、无视弱点削韧、弱点击破效率提升、抗性穿透提升、击破特攻提升',
#  '追加攻击、自身伤害提升、自身终结技伤害提升、无视弱点削韧',
#  '暴击率、能量、自身伤害提升、技能强化、秘技无受击、群攻',
#  '增伤、加攻、能量、速度提升、战技点恢复',
#  '治疗、效果解除、控制抵抗、能量、能量恢复、加攻、减攻、秘技无受击、持续治疗',
#  '召唤、追加攻击、暴击伤害、追加攻击易伤、自身伤害提升、能量、探索便利、自身召唤物行动提前',
#  '持续伤害、持续伤害立即触发、易伤、自身行动提前、自身伤害提升、群攻',
#  '攻击力、暴击率、消耗队友生命值、自身行动提前、效果抵抗、技能强化、特殊领域、自身终结技伤害提升、秘技无受击',
#  '伤害分摊、生命上限提升、暴击提升、减伤、全体控制抵抗、能量、治疗、秘技无受击、群攻、自身治疗',
#  '治疗、生命上限提升、受击概率提升、效果解除、能量、控制抵抗、持续治疗',
#  '技能强化、自身伤害提升、暴击伤害、能量、控制抵抗、快速移动、战技点抵扣、秘技无受击',
#  '持续伤害、追加攻击、能量、负面状态概率提升、持续伤害立即触发、秘技群攻',
#  '持续伤害、易伤、解除增益、能量、持续伤害立即触发',
#  '消耗生命值、自身伤害提升、技能强化、追加攻击、生命值回复量、自身追击伤害提升、群攻、自身治疗',
#  '治疗、解除增益、效果解除、控制抵抗、群攻、自动治疗、攻击治疗',
#  '加攻、暴击提升、暴伤提升、增伤、能量、负面效果抵抗、额外伤害、快速移动、削韧值',
#  '弱点植入、减防、随机、减攻、减速、减抗',
#  '召唤、追加攻击、速度、暴击伤害、能量、暴击率、群攻',
#  '抗性穿透、速度、额外回合、自身受击概率降低、自身行动提前、自身伤害提升、秘技无受击',
#  '效果解除、立即行动、加攻、增伤、自身行动提前、暴伤提升、加防、暴击率',
#  '行动延后、减速、额外伤害、附加伤害、易伤、能量、自身伤害提升、特殊领域、群攻',
#  '反击、自身减伤、自身受击概率提升、控制抵抗、自身效果解除、自身伤害提升、额外伤害、追加攻击、群攻',
#  '群体护盾、附加伤害、攻击力、自身受击概率提升、能量、冻结、自身复活、自身治疗',
#  '能量、追加攻击、暴击率、持续伤害、自身伤害提升、特殊领域、群攻、火易伤',
#  '治疗、生命上限提升、减伤、队友复活、受击治疗',
#  '暴击率、暴击伤害、自身受击概率降低、追加攻击、附加伤害、效果抵抗、速度、冻结',
#  '攻击力、秘技治疗、能量、防御力、自身伤害提升',
#  '嘲讽、自身减伤、群体护盾、技能强化、自身护盾、攻击力、能量、减伤、群攻、自身治疗',
#  '抗性穿透、减速、攻击力、自身受击概率降低、速度、自身伤害提升',
#  '加攻、速度提升、额外伤害、持续伤害、增伤、防御力',
#  '效果解除、单体护盾、反击、受击概率提升、附加伤害、追加攻击、冻结、群攻',
#  '技能强化、持续伤害、附加伤害、能量、自身行动提前、控制抵抗、自身治疗',
#  '解除增益、减防、能量、效果命中提升、自身伤害提升、群攻',
#  '额外伤害、持续伤害、行动延后、能量、自身减伤、秘技无受击、群攻、持续伤害易伤',
#  '持续伤害、附加伤害、能量、攻击力、群攻',
#  '治疗、减伤、效果解除、持续治疗、治疗量',
#  '',
#  '消耗生命值、伤害抵抗、持续伤害抵抗、自身伤害提升、自身治疗',
#  '追加攻击、攻击力、控制抵抗、自身伤害提升、群攻',
#  '技能强化、随机、攻击力、战技点恢复、速度、自身伤害提升、群攻',
#  '加攻、增伤、附加伤害、能量恢复、能量、速度']

# %% [markdown]
# len() is used again to check that all information about the 65 current total characters are obtained.

# %%
len(char_tag1)
# Out:
# 65

# %% [markdown]
# Similarly, html tag span is used but class is equal to tag-data-2 instead.

# %%
span2 = table_char.find_all('span', class_="tag-data-2")

char_tag2 = [item.text for item in span2]

char_tag2
# Out:
# ['忆灵、高速主C、回能、抗性穿透、无视防御、易伤',
#  '对群输出、攻击强化、行动提前',
#  '忆灵、真实伤害、回能',
#  '效果解除、立即行动、增伤、暴击率提升、暴击伤害提升、能量恢复、能量、召唤物立即行动、战技点恢复、无视防御力',
#  '击破特攻提升、无视弱点削韧、行动延后、减防、超击破、击破特攻、战技点恢复、击破易伤、弱点击破效率提升、能量、行动提前',
#  '技能强化、无视弱点削韧、群攻、额外回合、弱点击破效率、击破特攻、额外伤害、伤害倍率、快速移动、秘技无受击、能量、超击破、击破易伤、削韧值、自身无视防御力、速度提升',
#  '召唤、自身召唤物行动提前、治疗、击破易伤、群攻、额外伤害、追加攻击、攻击力、治疗量、能量、减抗、减防、击破特攻提升、弱点击破效率、额外伤害次数增加',
#  '追加攻击、无视弱点削韧、伤害倍率、自身伤害提升、攻击力、暴击伤害、快速移动、秘技牵引、特殊能量、伤害额外提高、削韧值、抗性穿透、速度',
#  '追加攻击、行动提前、战技点恢复、追加攻击易伤、附加伤害、伤害倍率、暴伤提升、能量、自身伤害提升',
#  '终结技易伤、易伤、持续伤害、特殊领域、群攻、攻击力、能量、减抗、增伤、持续伤害倍率',
#  '反击、自身治疗、能量、嘲讽、暴击伤害、额外伤害、自身减伤、攻击力、抗性穿透、效果抵抗、暴击率、自身无视防御力、自身终结技伤害提升、额外伤害次数增加',
#  '速度提升、附加伤害、技能强化、削韧值、立即行动、自身伤害提升。攻击段数提升、能量、击破特攻提升、行动提前、暴伤提升、暴击伤害、追加攻击、速度',
#  '追加攻击、暴击伤害、攻击力、群攻、速度提升、额外伤害、消耗队友生命值、自身追击伤害提升、秘技无受击、秘技群攻、抗性穿透、暴击率、自身无视防御力',
#  '技能强化、击破特攻、弱点击破效率、速度、弱点植入、无视弱点削韧、秘技群攻、秘技无受击、消耗生命值、能量、自身减伤、自身治疗、快速移动、自身行动提前、效果抵抗、超击破、削韧值、自身击破易伤、自身效果解除、抗性穿透、效果抵抗、自身无视防御力、额外回合',
#  '强化技能、弱点植入、嘲讽、行动延后、能量、暴击率、暴击伤害、自身减伤、自身易伤、击破特攻、战技点恢复、自身无视防御力、额外伤害',
#  '立即行动、能量、特殊领域、秘技诱敌、秘技无受击、增伤、加攻、附加伤害、控制抵抗、暴伤提升、自身行动提前、减抗、效果解除、速度提升',
#  '能量、击破特攻提升、超击破、行动延后、战技点恢复、能量恢复效率、额外伤害次数增加、额外次数',
#  '群体护盾、护盾叠加、随机、暴伤提升、效果抵抗提升、控制抵抗、追加攻击、加防、暴击率、减抗、攻击段数提升、自身伤害提升、防御力',
#  '特殊能量、无视弱点削韧、减抗、负面效果参照、探索便利、秘技无受击、自身普攻伤害提升、自身战技伤害提升、自身终结技伤害提升、自身伤害提升、额外伤害、群攻、快速移动、伤害额外提高、抗性穿透、暴击率、终结技易伤',
#  '技能强化、治疗、群攻、自身行动提前、攻击治疗、击破易伤、治疗量、击破特攻、弱点击破效率、效果抵抗、效果抵抗提升、效果解除、能量',
#  '暴击伤害、行动提前、战技点恢复、增伤、战技点上限、秘技无受击、加攻、能量、无视防御力',
#  '持续伤害、减防、自身伤害提升、额外效果、易伤、群攻、自身无视防御力、减抗、效果抵抗降低、能量',
#  '暴击伤害、效果命中、特殊领域、能量、附加伤害、战技点恢复、冻结、秘技无受击、伤害倍率、减防、自身伤害提升',
#  '追加攻击、负面效果参照、暴击率、暴击伤害、效果抵抗降低、自身伤害提升、特殊领域、减速、秘技无受击、能量、自身追击伤害提升、额外伤害',
#  '速度提升、增伤、能量、行动延后、无视弱点削韧、弱点击破效率提升、抗性穿透提升、击破特攻提升、伤害倍率、加攻、无视防御力',
#  '追加攻击、自身伤害提升、自身终结技伤害提升、无视弱点削韧、击破特攻、自身治疗、自身追击伤害提升',
#  '暴击率、能量、自身伤害提升、技能强化、秘技无受击、群攻',
#  '增伤、加攻、能量、速度提升、战技点恢复',
#  '治疗、效果解除、控制抵抗、能量、能量恢复、加攻、减攻、秘技无受击、持续治疗、治疗量',
#  '召唤、追加攻击、暴击伤害、追加攻击易伤、自身伤害提升、能量、探索便利、自身召唤物行动提前',
#  '持续伤害、持续伤害立即触发、易伤、自身行动提前、自身伤害提升、群攻',
#  '攻击力、暴击率、消耗队友生命值、自身行动提前、效果抵抗、技能强化、特殊领域、自身终结技伤害提升、秘技无受击',
#  '伤害分摊、生命上限提升、暴击提升、减伤、全体控制抵抗、能量、治疗、秘技无受击、群攻、自身治疗、我方复活、暴伤提升、自身终结技伤害提升',
#  '治疗、生命上限提升、受击概率提升、效果解除、能量、控制抵抗、持续治疗、治疗量',
#  '技能强化、自身伤害提升、暴击伤害、能量、控制抵抗、快速移动、战技点抵扣、秘技无受击',
#  '持续伤害、追加攻击、能量、负面状态概率提升、持续伤害立即触发、秘技群攻',
#  '持续伤害、易伤、解除增益、能量、持续伤害立即触发',
#  '消耗生命值、自身伤害提升、技能强化、追加攻击、生命值回复量、自身追击伤害提升、群攻、自身治疗',
#  '治疗、解除增益、效果解除、控制抵抗、群攻、自动治疗、攻击治疗、治疗量',
#  '加攻、暴击提升、暴伤提升、增伤、能量、负面效果抵抗、额外伤害、快速移动、削韧值',
#  '弱点植入、减防、随机、减攻、减速、减抗、自身伤害提高、自身能量恢复、附加伤害',
#  '召唤、追加攻击、速度、暴击伤害、能量、暴击率、群攻、伤害倍率、易伤、自身战技伤害提升、自身普攻伤害提升、自身终结技伤害提升',
#  '抗性穿透、速度、额外回合、自身受击概率降低、自身行动提前、自身伤害提升、秘技无受击',
#  '效果解除、立即行动、加攻、增伤、自身行动提前、暴伤提升、加防、暴击率',
#  '行动延后、减速、额外伤害、附加伤害、易伤、能量、自身伤害提升、特殊领域、群攻',
#  '反击、自身减伤、自身受击概率提升、控制抵抗、自身效果解除、自身伤害提升、额外伤害、追加攻击、群攻',
#  '群体护盾、附加伤害、攻击力、自身受击概率提升、能量、冻结、自身复活、自身治疗',
#  '能量、追加攻击、暴击率、持续伤害、自身伤害提升、特殊领域、群攻、火易伤',
#  '治疗、生命上限提升、减伤、队友复活、受击治疗、回能、增伤、治疗量、额外复活',
#  '暴击率、暴击伤害、自身受击概率降低、追加攻击、附加伤害、效果抵抗、速度、冻结',
#  '攻击力、秘技治疗、能量、防御力、自身伤害提升',
#  '嘲讽、自身减伤、群体护盾、技能强化、自身护盾、攻击力、能量、减伤、群攻、自身治疗',
#  '抗性穿透、减速、攻击力、自身受击概率降低、速度、自身伤害提升',
#  '加攻、速度提升、额外伤害、持续伤害、增伤、防御力',
#  '效果解除、单体护盾、反击、受击概率提升、附加伤害、追加攻击、冻结、群攻、治疗、能量、自身追击伤害提升',
#  '技能强化、持续伤害、附加伤害、能量、自身行动提前、控制抵抗、自身治疗',
#  '解除增益、减防、能量、效果命中提升、自身伤害提升、群攻',
#  '额外伤害、持续伤害、行动延后、能量、自身减伤、秘技无受击、群攻、持续伤害易伤',
#  '持续伤害、附加伤害、能量、攻击力、群攻',
#  '治疗、减伤、效果解除、持续治疗、治疗量',
#  '',
#  '消耗生命值、伤害抵抗、持续伤害抵抗、自身伤害提升、自身治疗',
#  '追加攻击、攻击力、控制抵抗、自身伤害提升、群攻',
#  '技能强化、随机、攻击力、战技点恢复、速度、自身伤害提升、群攻',
#  '加攻、增伤、附加伤害、能量恢复、能量、速度']

# %% [markdown]
# All information about 65 current total characters are obtained for the final section.

# %%
len(char_tag2)
# Out:
# 65

# %% [markdown]
# Before converting all the information into a Python Pandas Dataframe, all information about one single character has to be stored into a list whereby each list represents all the information about one character. After that, all of the lists representing different characters are stored into another list to create a nested list. Since length of char_tag1 or char_tag2 always equal to the total number of characters, it is used in the for loop to loop through the amount of times equal to it.

# %%
all_char = []

for i in range(len(char_tag1)):
    chunk1 = char_info[i * 4:(i + 1) * 4]
    chunk2 = char_info2[i * 7:(i + 1) * 7]
    chunk3 = [char_tag1[i]]
    chunk4 = [char_tag2[i]]

    combined = chunk1 + chunk2 + chunk3 + chunk4
    all_char.append(combined)

all_char
# Out:
# [['阿格莱雅',
#   '5星',
#   '记忆',
#   '雷',
#   '女',
#   '翁法罗斯',
#   '1242',
#   '699',
#   '485',
#   '102',
#   '350',
#   '忆灵、高速主C',
#   '忆灵、高速主C、回能、抗性穿透、无视防御、易伤'],
#  ['大黑塔',
#   '5星',
#   '智识',
#   '冰',
#   '女',
#   '空间站「黑塔」',
#   '1164',
#   '679',
#   '485',
#   '99',
#   '220',
#   '对群输出、攻击强化',
#   '对群输出、攻击强化、行动提前'],
#  ['开拓者•记忆',
#   '5星',
#   '记忆',
#   '冰',
#   '男, 女',
#   '星穹列车',
#   '1203',
#   '620',
#   '460',
#   '100',
#   '160',
#   '忆灵、真实伤害',
#   '忆灵、真实伤害、回能'],
#  ['星期日',
#   '5星',
#   '同谐',
#   '虚数',
#   '男',
#   '银河',
#   '1241',
#   '640',
#   '533',
#   '96',
#   '130',
#   '效果解除、立即行动、增伤、暴击率提升、暴击伤害提升、能量恢复、能量、召唤物立即行动、战技点恢复',
#   '效果解除、立即行动、增伤、暴击率提升、暴击伤害提升、能量恢复、能量、召唤物立即行动、战技点恢复、无视防御力'],
#  ['忘归人',
#   '5星',
#   '虚无',
#   '火',
#   '女',
#   '仙舟「罗浮」',
#   '1125',
#   '582',
#   '558',
#   '102',
#   '130',
#   '击破特攻提升、无视弱点削韧、行动延后、减防、超击破、击破特攻、战技点恢复',
#   '击破特攻提升、无视弱点削韧、行动延后、减防、超击破、击破特攻、战技点恢复、击破易伤、弱点击破效率提升、能量、行动提前'],
#  ['乱破',
#   '5星',
#   '智识',
#   '虚数',
#   '女',
#   '巡海游侠',
#   '1086',
#   '717',
#   '460',
#   '96',
#   '140',
#   '技能强化、无视弱点削韧、群攻、额外回合、弱点击破效率、击破特攻、额外伤害、伤害倍率、快速移动、秘技无受击、能量、超击破、击破易伤',
#   '技能强化、无视弱点削韧、群攻、额外回合、弱点击破效率、击破特攻、额外伤害、伤害倍率、快速移动、秘技无受击、能量、超击破、击破易伤、削韧值、自身无视防御力、速度提升'],
#  ['灵砂',
#   '5星',
#   '丰饶',
#   '火',
#   '女',
#   '仙舟「罗浮」',
#   '1358',
#   '679',
#   '437',
#   '98',
#   '110',
#   '召唤、自身召唤物行动提前、治疗、击破易伤、群攻、额外伤害、追加攻击、攻击力、治疗量、能量',
#   '召唤、自身召唤物行动提前、治疗、击破易伤、群攻、额外伤害、追加攻击、攻击力、治疗量、能量、减抗、减防、击破特攻提升、弱点击破效率、额外伤害次数增加'],
#  ['飞霄',
#   '5星',
#   '巡猎',
#   '风',
#   '女',
#   '仙舟「曜青」',
#   '1047',
#   '601',
#   '388',
#   '112',
#   '12点【飞黄】',
#   '追加攻击、无视弱点削韧、伤害倍率、自身伤害提升、攻击力、暴击伤害、快速移动、秘技牵引、特殊能量',
#   '追加攻击、无视弱点削韧、伤害倍率、自身伤害提升、攻击力、暴击伤害、快速移动、秘技牵引、特殊能量、伤害额外提高、削韧值、抗性穿透、速度'],
#  ['貊泽',
#   '4星',
#   '巡猎',
#   '雷',
#   '男',
#   '仙舟「曜青」',
#   '811',
#   '599',
#   '352',
#   '111',
#   '120',
#   '追加攻击、行动提前、战技点恢复、追加攻击易伤、附加伤害',
#   '追加攻击、行动提前、战技点恢复、追加攻击易伤、附加伤害、伤害倍率、暴伤提升、能量、自身伤害提升'],
#  ['椒丘',
#   '5星',
#   '虚无',
#   '火',
#   '男',
#   '仙舟「曜青」',
#   '1358',
#   '601',
#   '509',
#   '98',
#   '100',
#   '终结技易伤、易伤、持续伤害、特殊领域、群攻、攻击力、能量',
#   '终结技易伤、易伤、持续伤害、特殊领域、群攻、攻击力、能量、减抗、增伤、持续伤害倍率'],
#  ['云璃',
#   '5星',
#   '毁灭',
#   '物理',
#   '女',
#   '仙舟「朱明」',
#   '1358',
#   '679',
#   '460',
#   '94',
#   '240',
#   '反击、自身治疗、能量、嘲讽、暴击伤害、额外伤害、自身减伤、攻击力',
#   '反击、自身治疗、能量、嘲讽、暴击伤害、额外伤害、自身减伤、攻击力、抗性穿透、效果抵抗、暴击率、自身无视防御力、自身终结技伤害提升、额外伤害次数增加'],
#  ['三月七•巡猎',
#   '4星',
#   '巡猎',
#   '虚数',
#   '女',
#   '星穹列车',
#   '1058',
#   '564',
#   '441',
#   '102',
#   '110',
#   '速度提升、附加伤害、技能强化、削韧值、立即行动、自身伤害提升。攻击段数提升、能量、击破特攻提升、行动提前、暴伤提升',
#   '速度提升、附加伤害、技能强化、削韧值、立即行动、自身伤害提升。攻击段数提升、能量、击破特攻提升、行动提前、暴伤提升、暴击伤害、追加攻击、速度'],
#  ['翡翠',
#   '5星',
#   '智识',
#   '量子',
#   '女',
#   '星际和平公司',
#   '1086',
#   '659',
#   '509',
#   '103',
#   '140',
#   '追加攻击、暴击伤害、攻击力、群攻、速度提升、额外伤害、消耗队友生命值、自身追击伤害提升、秘技无受击、秘技群攻',
#   '追加攻击、暴击伤害、攻击力、群攻、速度提升、额外伤害、消耗队友生命值、自身追击伤害提升、秘技无受击、秘技群攻、抗性穿透、暴击率、自身无视防御力'],
#  ['流萤',
#   '5星',
#   '毁灭',
#   '火',
#   '女',
#   '星核猎手',
#   '814',
#   '523',
#   '776',
#   '104',
#   '240',
#   '技能强化、击破特攻、弱点击破效率、速度、弱点植入、无视弱点削韧、秘技群攻、秘技无受击、消耗生命值、能量、自身减伤、自身治疗、快速移动、自身行动提前、效果抵抗、超击破、削韧值、自身击破易伤、自身效果解除',
#   '技能强化、击破特攻、弱点击破效率、速度、弱点植入、无视弱点削韧、秘技群攻、秘技无受击、消耗生命值、能量、自身减伤、自身治疗、快速移动、自身行动提前、效果抵抗、超击破、削韧值、自身击破易伤、自身效果解除、抗性穿透、效果抵抗、自身无视防御力、额外回合'],
#  ['波提欧',
#   '5星',
#   '巡猎',
#   '物理',
#   '男',
#   '巡海游侠',
#   '1203',
#   '620',
#   '436',
#   '107',
#   '115',
#   '强化技能、弱点植入、嘲讽、行动延后、能量、暴击率、暴击伤害、自身减伤、自身易伤',
#   '强化技能、弱点植入、嘲讽、行动延后、能量、暴击率、暴击伤害、自身减伤、自身易伤、击破特攻、战技点恢复、自身无视防御力、额外伤害'],
#  ['知更鸟',
#   '5星',
#   '同谐',
#   '物理',
#   '女',
#   '匹诺康尼',
#   '1280',
#   '640',
#   '485',
#   '102',
#   '160',
#   '立即行动、能量、特殊领域、秘技诱敌、秘技无受击、增伤、加攻、附加伤害、控制抵抗、暴伤提升、自身行动提前',
#   '立即行动、能量、特殊领域、秘技诱敌、秘技无受击、增伤、加攻、附加伤害、控制抵抗、暴伤提升、自身行动提前、减抗、效果解除、速度提升'],
#  ['开拓者•同谐',
#   '5星',
#   '同谐',
#   '虚数',
#   '男, 女',
#   '星穹列车',
#   '1086',
#   '446',
#   '679',
#   '105',
#   '140',
#   '能量、击破特攻提升、超击破、行动延后',
#   '能量、击破特攻提升、超击破、行动延后、战技点恢复、能量恢复效率、额外伤害次数增加、额外次数'],
#  ['砂金',
#   '5星',
#   '存护',
#   '虚数',
#   '男',
#   '星际和平公司',
#   '1203',
#   '446',
#   '654',
#   '106',
#   '110',
#   '群体护盾、护盾叠加、随机、暴伤提升、效果抵抗提升、控制抵抗、追加攻击、加防、暴击率',
#   '群体护盾、护盾叠加、随机、暴伤提升、效果抵抗提升、控制抵抗、追加攻击、加防、暴击率、减抗、攻击段数提升、自身伤害提升、防御力'],
#  ['黄泉',
#   '5星',
#   '虚无',
#   '雷',
#   '女',
#   '自灭者',
#   '1125',
#   '698',
#   '436',
#   '101',
#   '9点【残梦】',
#   '特殊能量、无视弱点削韧、减抗、负面效果参照、探索便利、秘技无受击、自身普攻伤害提升、自身战技伤害提升、自身终结技伤害提升、自身伤害提升、额外伤害、群攻、快速移动、伤害额外提高',
#   '特殊能量、无视弱点削韧、减抗、负面效果参照、探索便利、秘技无受击、自身普攻伤害提升、自身战技伤害提升、自身终结技伤害提升、自身伤害提升、额外伤害、群攻、快速移动、伤害额外提高、抗性穿透、暴击率、终结技易伤'],
#  ['加拉赫',
#   '4星',
#   '丰饶',
#   '火',
#   '男',
#   '匹诺康尼',
#   '1305',
#   '529',
#   '441',
#   '98',
#   '110',
#   '技能强化、治疗、群攻、自身行动提前、攻击治疗、击破易伤、治疗量',
#   '技能强化、治疗、群攻、自身行动提前、攻击治疗、击破易伤、治疗量、击破特攻、弱点击破效率、效果抵抗、效果抵抗提升、效果解除、能量'],
#  ['花火',
#   '5星',
#   '同谐',
#   '量子',
#   '女',
#   '假面愚者',
#   '1397',
#   '523',
#   '485',
#   '101',
#   '110',
#   '暴击伤害、行动提前、战技点恢复、增伤、战技点上限、秘技无受击、加攻、能量',
#   '暴击伤害、行动提前、战技点恢复、增伤、战技点上限、秘技无受击、加攻、能量、无视防御力'],
#  ['黑天鹅',
#   '5星',
#   '虚无',
#   '风',
#   '女',
#   '流光忆庭',
#   '1086',
#   '659',
#   '485',
#   '102',
#   '120',
#   '持续伤害、减防、自身伤害提升、额外效果、易伤、群攻、自身无视防御力',
#   '持续伤害、减防、自身伤害提升、额外效果、易伤、群攻、自身无视防御力、减抗、效果抵抗降低、能量'],
#  ['米沙',
#   '4星',
#   '毁灭',
#   '冰',
#   '男',
#   '匹诺康尼',
#   '1270',
#   '599',
#   '396',
#   '96',
#   '100',
#   '暴击伤害、效果命中、特殊领域、能量、附加伤害、战技点恢复、冻结、秘技无受击',
#   '暴击伤害、效果命中、特殊领域、能量、附加伤害、战技点恢复、冻结、秘技无受击、伤害倍率、减防、自身伤害提升'],
#  ['真理医生',
#   '5星',
#   '巡猎',
#   '虚数',
#   '男',
#   '博识学会',
#   '1047',
#   '776',
#   '460',
#   '103',
#   '140',
#   '追加攻击、负面效果参照、暴击率、暴击伤害、效果抵抗降低、自身伤害提升、特殊领域、减速、秘技无受击',
#   '追加攻击、负面效果参照、暴击率、暴击伤害、效果抵抗降低、自身伤害提升、特殊领域、减速、秘技无受击、能量、自身追击伤害提升、额外伤害'],
#  ['阮•梅',
#   '5星',
#   '同谐',
#   '冰',
#   '女',
#   '空间站「黑塔」',
#   '1086',
#   '659',
#   '485',
#   '104',
#   '130',
#   '速度提升、增伤、能量、行动延后、无视弱点削韧、弱点击破效率提升、抗性穿透提升、击破特攻提升',
#   '速度提升、增伤、能量、行动延后、无视弱点削韧、弱点击破效率提升、抗性穿透提升、击破特攻提升、伤害倍率、加攻、无视防御力'],
#  ['雪衣',
#   '4星',
#   '毁灭',
#   '量子',
#   '女',
#   '仙舟「罗浮」',
#   '1058',
#   '599',
#   '396',
#   '103',
#   '120',
#   '追加攻击、自身伤害提升、自身终结技伤害提升、无视弱点削韧',
#   '追加攻击、自身伤害提升、自身终结技伤害提升、无视弱点削韧、击破特攻、自身治疗、自身追击伤害提升'],
#  ['银枝',
#   '5星',
#   '智识',
#   '物理',
#   '男',
#   '纯美骑士团',
#   '1047',
#   '737',
#   '363',
#   '103',
#   '180',
#   '暴击率、能量、自身伤害提升、技能强化、秘技无受击、群攻',
#   '暴击率、能量、自身伤害提升、技能强化、秘技无受击、群攻'],
#  ['寒鸦',
#   '4星',
#   '同谐',
#   '物理',
#   '女',
#   '仙舟「罗浮」',
#   '917',
#   '564',
#   '352',
#   '110',
#   '140',
#   '增伤、加攻、能量、速度提升、战技点恢复',
#   '增伤、加攻、能量、速度提升、战技点恢复'],
#  ['藿藿',
#   '5星',
#   '丰饶',
#   '风',
#   '女',
#   '仙舟「罗浮」',
#   '1358',
#   '601',
#   '509',
#   '98',
#   '140',
#   '治疗、效果解除、控制抵抗、能量、能量恢复、加攻、减攻、秘技无受击、持续治疗',
#   '治疗、效果解除、控制抵抗、能量、能量恢复、加攻、减攻、秘技无受击、持续治疗、治疗量'],
#  ['托帕&账账',
#   '5星',
#   '巡猎',
#   '火',
#   '女',
#   '星际和平公司',
#   '931',
#   '622',
#   '412',
#   '110',
#   '130',
#   '召唤、追加攻击、暴击伤害、追加攻击易伤、自身伤害提升、能量、探索便利、自身召唤物行动提前',
#   '召唤、追加攻击、暴击伤害、追加攻击易伤、自身伤害提升、能量、探索便利、自身召唤物行动提前'],
#  ['桂乃芬',
#   '4星',
#   '虚无',
#   '火',
#   '女',
#   '仙舟「罗浮」',
#   '882',
#   '582',
#   '441',
#   '106',
#   '120',
#   '持续伤害、持续伤害立即触发、易伤、自身行动提前、自身伤害提升、群攻',
#   '持续伤害、持续伤害立即触发、易伤、自身行动提前、自身伤害提升、群攻'],
#  ['镜流',
#   '5星',
#   '毁灭',
#   '冰',
#   '女',
#   '仙舟「罗浮」',
#   '1435',
#   '679',
#   '485',
#   '96',
#   '140',
#   '攻击力、暴击率、消耗队友生命值、自身行动提前、效果抵抗、技能强化、特殊领域、自身终结技伤害提升、秘技无受击',
#   '攻击力、暴击率、消耗队友生命值、自身行动提前、效果抵抗、技能强化、特殊领域、自身终结技伤害提升、秘技无受击'],
#  ['符玄',
#   '5星',
#   '存护',
#   '量子',
#   '女',
#   '仙舟「罗浮」',
#   '1474',
#   '465',
#   '606',
#   '100',
#   '135',
#   '伤害分摊、生命上限提升、暴击提升、减伤、全体控制抵抗、能量、治疗、秘技无受击、群攻、自身治疗',
#   '伤害分摊、生命上限提升、暴击提升、减伤、全体控制抵抗、能量、治疗、秘技无受击、群攻、自身治疗、我方复活、暴伤提升、自身终结技伤害提升'],
#  ['玲可',
#   '4星',
#   '丰饶',
#   '量子',
#   '女',
#   '贝洛伯格',
#   '1058',
#   '493',
#   '551',
#   '100',
#   '100',
#   '治疗、生命上限提升、受击概率提升、效果解除、能量、控制抵抗、持续治疗',
#   '治疗、生命上限提升、受击概率提升、效果解除、能量、控制抵抗、持续治疗、治疗量'],
#  ['丹恒•饮月',
#   '5星',
#   '毁灭',
#   '虚数',
#   '男',
#   '仙舟「罗浮」',
#   '1241',
#   '698',
#   '363',
#   '102',
#   '140',
#   '技能强化、自身伤害提升、暴击伤害、能量、控制抵抗、快速移动、战技点抵扣、秘技无受击',
#   '技能强化、自身伤害提升、暴击伤害、能量、控制抵抗、快速移动、战技点抵扣、秘技无受击'],
#  ['卡芙卡',
#   '5星',
#   '虚无',
#   '雷',
#   '女',
#   '星核猎手',
#   '1086',
#   '679',
#   '485',
#   '100',
#   '120',
#   '持续伤害、追加攻击、能量、负面状态概率提升、持续伤害立即触发、秘技群攻',
#   '持续伤害、追加攻击、能量、负面状态概率提升、持续伤害立即触发、秘技群攻'],
#  ['卢卡',
#   '4星',
#   '虚无',
#   '物理',
#   '男',
#   '贝洛伯格',
#   '917',
#   '582',
#   '485',
#   '103',
#   '130',
#   '持续伤害、易伤、解除增益、能量、持续伤害立即触发',
#   '持续伤害、易伤、解除增益、能量、持续伤害立即触发'],
#  ['刃',
#   '5星',
#   '毁灭',
#   '风',
#   '男',
#   '星核猎手',
#   '1358',
#   '543',
#   '485',
#   '97',
#   '130',
#   '消耗生命值、自身伤害提升、技能强化、追加攻击、生命值回复量、自身追击伤害提升、群攻、自身治疗',
#   '消耗生命值、自身伤害提升、技能强化、追加攻击、生命值回复量、自身追击伤害提升、群攻、自身治疗'],
#  ['罗刹',
#   '5星',
#   '丰饶',
#   '虚数',
#   '男',
#   '仙舟「罗浮」',
#   '1280',
#   '756',
#   '363',
#   '101',
#   '100',
#   '治疗、解除增益、效果解除、控制抵抗、群攻、自动治疗、攻击治疗',
#   '治疗、解除增益、效果解除、控制抵抗、群攻、自动治疗、攻击治疗、治疗量'],
#  ['驭空',
#   '4星',
#   '同谐',
#   '虚数',
#   '女',
#   '仙舟「罗浮」',
#   '917',
#   '599',
#   '374',
#   '107',
#   '130',
#   '加攻、暴击提升、暴伤提升、增伤、能量、负面效果抵抗、额外伤害、快速移动、削韧值',
#   '加攻、暴击提升、暴伤提升、增伤、能量、负面效果抵抗、额外伤害、快速移动、削韧值'],
#  ['银狼',
#   '5星',
#   '虚无',
#   '量子',
#   '女',
#   '星核猎手',
#   '1047',
#   '640',
#   '460',
#   '107',
#   '110',
#   '弱点植入、减防、随机、减攻、减速、减抗',
#   '弱点植入、减防、随机、减攻、减速、减抗、自身伤害提高、自身能量恢复、附加伤害'],
#  ['景元',
#   '5星',
#   '智识',
#   '雷',
#   '男',
#   '仙舟「罗浮」',
#   '1164',
#   '698',
#   '485',
#   '99',
#   '130',
#   '召唤、追加攻击、速度、暴击伤害、能量、暴击率、群攻',
#   '召唤、追加攻击、速度、暴击伤害、能量、暴击率、群攻、伤害倍率、易伤、自身战技伤害提升、自身普攻伤害提升、自身终结技伤害提升'],
#  ['希儿',
#   '5星',
#   '巡猎',
#   '量子',
#   '女',
#   '贝洛伯格',
#   '931',
#   '640',
#   '363',
#   '115',
#   '120',
#   '抗性穿透、速度、额外回合、自身受击概率降低、自身行动提前、自身伤害提升、秘技无受击',
#   '抗性穿透、速度、额外回合、自身受击概率降低、自身行动提前、自身伤害提升、秘技无受击'],
#  ['布洛妮娅',
#   '5星',
#   '同谐',
#   '风',
#   '女',
#   '贝洛伯格',
#   '1241',
#   '582',
#   '533',
#   '99',
#   '120',
#   '效果解除、立即行动、加攻、增伤、自身行动提前、暴伤提升、加防、暴击率',
#   '效果解除、立即行动、加攻、增伤、自身行动提前、暴伤提升、加防、暴击率'],
#  ['瓦尔特',
#   '5星',
#   '虚无',
#   '虚数',
#   '男',
#   '星穹列车',
#   '1125',
#   '620',
#   '509',
#   '102',
#   '120',
#   '行动延后、减速、额外伤害、附加伤害、易伤、能量、自身伤害提升、特殊领域、群攻',
#   '行动延后、减速、额外伤害、附加伤害、易伤、能量、自身伤害提升、特殊领域、群攻'],
#  ['克拉拉',
#   '5星',
#   '毁灭',
#   '物理',
#   '女',
#   '贝洛伯格',
#   '1241',
#   '737',
#   '485',
#   '90',
#   '110',
#   '反击、自身减伤、自身受击概率提升、控制抵抗、自身效果解除、自身伤害提升、额外伤害、追加攻击、群攻',
#   '反击、自身减伤、自身受击概率提升、控制抵抗、自身效果解除、自身伤害提升、额外伤害、追加攻击、群攻'],
#  ['杰帕德',
#   '5星',
#   '存护',
#   '冰',
#   '男',
#   '贝洛伯格',
#   '1397',
#   '543',
#   '654',
#   '92',
#   '100',
#   '群体护盾、附加伤害、攻击力、自身受击概率提升、能量、冻结、自身复活、自身治疗',
#   '群体护盾、附加伤害、攻击力、自身受击概率提升、能量、冻结、自身复活、自身治疗'],
#  ['姬子',
#   '5星',
#   '智识',
#   '火',
#   '女',
#   '星穹列车',
#   '1047',
#   '756',
#   '436',
#   '96',
#   '120',
#   '能量、追加攻击、暴击率、持续伤害、自身伤害提升、特殊领域、群攻、火易伤',
#   '能量、追加攻击、暴击率、持续伤害、自身伤害提升、特殊领域、群攻、火易伤'],
#  ['白露',
#   '5星',
#   '丰饶',
#   '雷',
#   '女',
#   '仙舟「罗浮」',
#   '1319',
#   '562',
#   '485',
#   '98',
#   '100',
#   '治疗、生命上限提升、减伤、队友复活、受击治疗',
#   '治疗、生命上限提升、减伤、队友复活、受击治疗、回能、增伤、治疗量、额外复活'],
#  ['彦卿',
#   '5星',
#   '巡猎',
#   '冰',
#   '男',
#   '仙舟「罗浮」',
#   '892',
#   '679',
#   '412',
#   '109',
#   '140',
#   '暴击率、暴击伤害、自身受击概率降低、追加攻击、附加伤害、效果抵抗、速度、冻结',
#   '暴击率、暴击伤害、自身受击概率降低、追加攻击、附加伤害、效果抵抗、速度、冻结'],
#  ['开拓者•毁灭',
#   '5星',
#   '毁灭',
#   '物理',
#   '男, 女',
#   '星穹列车',
#   '1203',
#   '620',
#   '460',
#   '100',
#   '120',
#   '攻击力、秘技治疗、能量、防御力、自身伤害提升',
#   '攻击力、秘技治疗、能量、防御力、自身伤害提升'],
#  ['开拓者•存护',
#   '5星',
#   '存护',
#   '火',
#   '男, 女',
#   '星穹列车',
#   '1241',
#   '601',
#   '606',
#   '95',
#   '120',
#   '嘲讽、自身减伤、群体护盾、技能强化、自身护盾、攻击力、能量、减伤、群攻、自身治疗',
#   '嘲讽、自身减伤、群体护盾、技能强化、自身护盾、攻击力、能量、减伤、群攻、自身治疗'],
#  ['丹恒',
#   '4星',
#   '巡猎',
#   '风',
#   '男',
#   '星穹列车',
#   '882',
#   '546',
#   '396',
#   '110',
#   '100',
#   '抗性穿透、减速、攻击力、自身受击概率降低、速度、自身伤害提升',
#   '抗性穿透、减速、攻击力、自身受击概率降低、速度、自身伤害提升'],
#  ['艾丝妲',
#   '4星',
#   '同谐',
#   '火',
#   '女',
#   '空间站「黑塔」',
#   '1023',
#   '511',
#   '463',
#   '106',
#   '120',
#   '加攻、速度提升、额外伤害、持续伤害、增伤、防御力',
#   '加攻、速度提升、额外伤害、持续伤害、增伤、防御力'],
#  ['三月七',
#   '4星',
#   '存护',
#   '冰',
#   '女',
#   '星穹列车',
#   '1058',
#   '511',
#   '573',
#   '101',
#   '120',
#   '效果解除、单体护盾、反击、受击概率提升、附加伤害、追加攻击、冻结、群攻',
#   '效果解除、单体护盾、反击、受击概率提升、附加伤害、追加攻击、冻结、群攻、治疗、能量、自身追击伤害提升'],
#  ['虎克',
#   '4星',
#   '毁灭',
#   '火',
#   '女',
#   '贝洛伯格',
#   '1340',
#   '617',
#   '352',
#   '94',
#   '120',
#   '技能强化、持续伤害、附加伤害、能量、自身行动提前、控制抵抗、自身治疗',
#   '技能强化、持续伤害、附加伤害、能量、自身行动提前、控制抵抗、自身治疗'],
#  ['佩拉',
#   '4星',
#   '虚无',
#   '冰',
#   '女',
#   '贝洛伯格',
#   '987',
#   '546',
#   '463',
#   '105',
#   '110',
#   '解除增益、减防、能量、效果命中提升、自身伤害提升、群攻',
#   '解除增益、减防、能量、效果命中提升、自身伤害提升、群攻'],
#  ['桑博',
#   '4星',
#   '虚无',
#   '风',
#   '男',
#   '贝洛伯格',
#   '1023',
#   '617',
#   '396',
#   '102',
#   '120',
#   '额外伤害、持续伤害、行动延后、能量、自身减伤、秘技无受击、群攻、持续伤害易伤',
#   '额外伤害、持续伤害、行动延后、能量、自身减伤、秘技无受击、群攻、持续伤害易伤'],
#  ['希露瓦',
#   '4星',
#   '智识',
#   '雷',
#   '女',
#   '贝洛伯格',
#   '917',
#   '652',
#   '374',
#   '104',
#   '100',
#   '持续伤害、附加伤害、能量、攻击力、群攻',
#   '持续伤害、附加伤害、能量、攻击力、群攻'],
#  ['娜塔莎',
#   '4星',
#   '丰饶',
#   '物理',
#   '女',
#   '贝洛伯格',
#   '1164',
#   '476',
#   '507',
#   '98',
#   '90',
#   '治疗、减伤、效果解除、持续治疗、治疗量',
#   '治疗、减伤、效果解除、持续治疗、治疗量'],
#  ['素裳',
#   '4星',
#   '巡猎',
#   '物理',
#   '女',
#   '仙舟「罗浮」',
#   '917',
#   '564',
#   '418',
#   '107',
#   '120',
#   '',
#   ''],
#  ['阿兰',
#   '4星',
#   '毁灭',
#   '雷',
#   '男',
#   '空间站「黑塔」',
#   '1199',
#   '599',
#   '330',
#   '102',
#   '110',
#   '消耗生命值、伤害抵抗、持续伤害抵抗、自身伤害提升、自身治疗',
#   '消耗生命值、伤害抵抗、持续伤害抵抗、自身伤害提升、自身治疗'],
#  ['黑塔',
#   '4星',
#   '智识',
#   '冰',
#   '女',
#   '空间站「黑塔」',
#   '952',
#   '582',
#   '396',
#   '100',
#   '110',
#   '追加攻击、攻击力、控制抵抗、自身伤害提升、群攻',
#   '追加攻击、攻击力、控制抵抗、自身伤害提升、群攻'],
#  ['青雀',
#   '4星',
#   '智识',
#   '量子',
#   '女',
#   '仙舟「罗浮」',
#   '1023',
#   '652',
#   '441',
#   '98',
#   '140',
#   '技能强化、随机、攻击力、战技点恢复、速度、自身伤害提升、群攻',
#   '技能强化、随机、攻击力、战技点恢复、速度、自身伤害提升、群攻'],
#  ['停云',
#   '4星',
#   '同谐',
#   '雷',
#   '女',
#   '仙舟「罗浮」',
#   '846',
#   '529',
#   '396',
#   '112',
#   '130',
#   '加攻、增伤、附加伤害、能量恢复、能量、速度',
#   '加攻、增伤、附加伤害、能量恢复、能量、速度']]

# %% [markdown]
# After the nested list of characters is created, the nested list is converted into Python Pandas Dataframe with column names: 'Name', 'Rarity', 'Path', 'Element', 'Gender', 'Faction', 'HP lvl80', 'ATK lvl80', 'DEF lvl80', 'Speed', 'Energy_Cap', 'Char_Tag_1', 'Char_Tag_2' representing each of the information stored between characters.

# %%
hsr_df = pd.DataFrame(all_char, columns=['Name', 'Rarity', 'Path', 'Element', 'Gender', 'Faction', 'HP lvl80', 'ATK lvl80', 'DEF lvl80', 'Speed', 'Energy_Cap', 'Char_Tag_1', 'Char_Tag_2'])

# %% [markdown]
# Ultimately, the dataframe is converted into a CSV file and can be used for data analysis purposes.

# %%
hsr_df.to_csv('hsr_char_v3.0.csv', encoding="utf-8-sig")

# %% [markdown]
# References:
#
# *   星穹铁道 Wiki (CN Honkai: Star Rail Wiki): https://wiki.biligame.com/sr/%E8%A7%92%E8%89%B2%E7%AD%9B%E9%80%89
# *   Content web-scraped from the game wikipedia are provided in accordance with CC BY-NC-SA 4.0 as detailed in the game wikipedia page: https://creativecommons.org/licenses/by-nc-sa/4.0/
